# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshashi22/IT_Employee_Stimulation/blob/main/IT_EMPLOYEE_STIMULATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the dataset

data=pd.read_csv("/content/employee_data.csv")

# %%
print(data)
# Out:
#       ID Gender  Experience (Years)                      Position  Salary
# 0      1      F                   4               DevOps Engineer  109976
# 1      2      M                   6               DevOps Engineer  120088
# 2      3      M                  17                 Web Developer  181301
# 3      4      M                   7         Systems Administrator   77530
# 4      5      F                  13         Systems Administrator  152397
# ..   ...    ...                 ...                           ...     ...
# 395  396      F                  19     Cloud Solutions Architect  236045
# 396  397      F                  20                 Web Developer  182770
# 397  398      F                   9         Network Administrator   85550
# 398  399      M                  18  Database Administrator (DBA)  129996
# 399  400      F                  11           IT Security Analyst  169058
#
# [400 rows x 5 columns]

# %%
data
# Out:
#       ID Gender  Experience (Years)                      Position  Salary
# 0      1      F                   4               DevOps Engineer  109976
# 1      2      M                   6               DevOps Engineer  120088
# 2      3      M                  17                 Web Developer  181301
# 3      4      M                   7         Systems Administrator   77530
# 4      5      F                  13         Systems Administrator  152397
# ..   ...    ...                 ...                           ...     ...
# 395  396      F                  19     Cloud Solutions Architect  236045
# 396  397      F                  20                 Web Developer  182770
# 397  398      F                   9         Network Administrator   85550
# 398  399      M                  18  Database Administrator (DBA)  129996
# 399  400      F                  11           IT Security Analyst  169058
#
# [400 rows x 5 columns]

# %%
data.head()
# Out:
#    ID Gender  Experience (Years)               Position  Salary
# 0   1      F                   4        DevOps Engineer  109976
# 1   2      M                   6        DevOps Engineer  120088
# 2   3      M                  17          Web Developer  181301
# 3   4      M                   7  Systems Administrator   77530
# 4   5      F                  13  Systems Administrator  152397

# %%
data.tail()
# Out:
#       ID Gender  Experience (Years)                      Position  Salary
# 395  396      F                  19     Cloud Solutions Architect  236045
# 396  397      F                  20                 Web Developer  182770
# 397  398      F                   9         Network Administrator   85550
# 398  399      M                  18  Database Administrator (DBA)  129996
# 399  400      F                  11           IT Security Analyst  169058

# %%
data.shape
# Out:
# (400, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  400 non-null    int64
#  1   Gender              400 non-null    object
#  2   Experience (Years)  400 non-null    int64
#  3   Position            400 non-null    object
#  4   Salary              400 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 15.8+ KB

# %%
# checking for duplication

data.nunique()
# Out:
# ID                    400
# Gender                  2
# Experience (Years)     21
# Position               11
# Salary                400
# dtype: int64

# %%
# missing data values in the form of %

data.isnull().sum()*100/len(data)*100
# Out:
# ID                    0.0
# Gender                0.0
# Experience (Years)    0.0
# Position              0.0
# Salary                0.0
# dtype: float64

# %% [markdown]
# # **Exploratory Analysis**

# %% [markdown]
# # **Gender**

# %%
ax = sns.countplot(x='Gender',data=data)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
data.groupby(['Gender'], as_index=False)['Salary'].sum().sort_values(by='Salary', ascending=False)
# Out:
#   Gender    Salary
# 1      M  26419744
# 0      F  26260735

# %%
Salary_gen=data.groupby(['Gender'], as_index=False)['Salary'].sum().sort_values(by='Salary', ascending=False)

sns.barplot(x='Gender',y='Salary',data=Salary_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %% [markdown]
# # From the above graphs we can see that Male employees are more than female employees and they both get almost equal amount of salary

# %% [markdown]
# ## **Experience(Years)**

# %%
data.columns
# Out:
# Index(['ID', 'Gender', 'Experience (Years)', 'Position', 'Salary'], dtype='object')

# %%
ax=sns.countplot(data=data, x='Experience (Years)',hue='Gender')

for bars in ax.containers:
   ax.bar_label(bars)
   plt.show()

# %%
# Total salary vs Experience

Salary_gen = data.groupby(['Experience (Years)'],as_index=False)['Salary'].sum().sort_values(by='Salary',ascending=False)

sns.barplot(x='Experience (Years)',y='Salary',data=Salary_gen)
plt.show()

# %% [markdown]
# ## From the above graphs we can see that there are more experinced male than female in this company and salary gets fluctuated according to the experience

# %% [markdown]
# # **Position**

# %%
sns.set(rc={'figure.figsize':(30,5)})
ax=sns.countplot(data=data,x='Position')

for bars in ax.containers:
  ax.bar_label(bars)

# %%
Salary_gen= data.groupby(['Position'],as_index=False)['Salary'].sum().sort_values(by='Salary',ascending=False)
sns.set(rc={'figure.figsize':(30,5)})
sns.barplot(data = Salary_gen,x='Position',y='Salary')
plt.show()

# %% [markdown]
# # From the above graphs we can see that maximum number of employees are at Web Development position. IT Manager position gets the highest salary.

# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# ### **In this company there are maximum male employees which are experienced as well.Here, maximum number of employees are there in the Web Development position but IT Manager position gets highest salary.**
